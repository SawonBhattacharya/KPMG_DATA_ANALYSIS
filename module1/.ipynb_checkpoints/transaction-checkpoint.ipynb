# %%
import pandas as pd
import numpy as np
from functools import reduce
import re

# %%
df = pd.read_csv('data/transaction_KPMG.csv')
#df.set_index('transaction_id',inplace=True)
#df.head()

# %%
df.sort_index(axis=0)
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       25-02-2017        False
# 1                   2           3         3120       21-05-2017         True
# 2                   3          37          402       16-10-2017        False
# 3                   4          88         3135       31-08-2017        False
# 4                   5          78          787       01-10-2017         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       24-06-2017         True
# 19996           19997          41          127       09-11-2017         True
# 19997           19998          87         2284       14-04-2017         True
# 19998           19999           6         2764       03-07-2017        False
# 19999           20000          11         1144       22-09-2017         True
#
# ...

# %%
df.isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
#null values are dropped
df = df[df.online_order.notnull()]
df = df[df.brand.notnull()]
df = df[df.product_line.notnull()]
df = df[df.product_class.notnull()]
df = df[df.standard_cost.notnull()]
df = df[df.product_first_sold_date.notnull()]

# %%
df.isna().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
df.head(5)
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       25-02-2017        False
# 1               2           3         3120       21-05-2017         True
# 2               3          37          402       16-10-2017        False
# 3               4          88         3135       31-08-2017        False
# 4               5          78          787       01-10-2017         True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price standard_cost product_first_sold_date
# ...

# %%
#let's drop the orders which are offline or cancelled

# %%
df=df[df.order_status !='Cancelled']
df
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       25-02-2017        False
# 1                   2           3         3120       21-05-2017         True
# 2                   3          37          402       16-10-2017        False
# 3                   4          88         3135       31-08-2017        False
# 4                   5          78          787       01-10-2017         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       24-06-2017         True
# 19996           19997          41          127       09-11-2017         True
# 19997           19998          87         2284       14-04-2017         True
# 19998           19999           6         2764       03-07-2017        False
# 19999           20000          11         1144       22-09-2017         True
#
# ...

# %%
df=df[df.online_order !=False]
df
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 1                   2           3         3120       21-05-2017         True
# 4                   5          78          787       01-10-2017         True
# 5                   6          25         2339       08-03-2017         True
# 6                   7          22         1542       21-04-2017         True
# 9                  10          12         3262       30-08-2017         True
# ...               ...         ...          ...              ...          ...
# 19994           19995           9          718       13-05-2017         True
# 19995           19996          51         1018       24-06-2017         True
# 19996           19997          41          127       09-11-2017         True
# 19997           19998          87         2284       14-04-2017         True
# 19999           20000          11         1144       22-09-2017         True
#
# ...
